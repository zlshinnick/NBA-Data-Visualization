# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("./all_seasons.csv")

# %%
df = df.groupby("season").mean()

df=df[["player_height"]]

# %%
plt.figure(figsize=(20,10))

sns.lineplot(df.index,df.player_height)
plt.xticks(rotation=-30)

font1 = {'family':'arial','color':'black','size':20}
font2 = {'family':'arial','color':'black','size':12}

plt.xlabel("Season", fontdict = font2)
plt.ylabel("Height(CM)", fontdict = font2)
plt.title("Average Player Height per Season",fontdict = font1)
# Out:
# /Users/zachshinnick/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Average Player Height per Season')
